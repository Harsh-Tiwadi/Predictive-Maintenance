# %%
import pandas as pd
import numpy as np
import json

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
try:
    path = 'noteee.json'
    with open(path, 'r') as file:
        info = json.loads(file.read())
except FileNotFoundError:
    info = {}
    print(info)
    raise ValueError('info is empty')
info
# Out:
# {}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       2 path = 'noteee.json'
# ----> 3 with open(path, 'r') as file:
#       4     info = json.loads(file.read())
#
# File ~/lab/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'noteee.json'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       6     info = {}
#       7     print(info)
# ----> 8     raise ValueError('info is empty')
#       9 info
#
# ValueError: info is empty

# %%
i = len(info)
print(i)
info.update({})
# Out:
# 0

# %%
def save(model):
    x_train,x_test,y_train,y_test =     train_test(x,y)
    name = str(model.estimator)
    i = len(info)
    info.update({name+'_'+str(i+1):{'acc':accuracy_score(y_test,y_pred), 'best_p':model.best_params_}})
    with open(path, 'w') as file:
        file,write(json.dumps(info))

# %%
def train_test(x,y):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.21, random_state=42)
    scaler = MinMaxScaler()
    x_train_scaled = scaler.fit_transform(x_train)
    x_test_scaled = scaler.transform(x_test)
    return x_train_scaled,x_test_scaled,y_train,y_test

# %%
df = pd.read_parquet("../data/aircraft engine/PM_train.parquet")
df['RULC'] = df['RUL'].map(lambda x: 1 if x<30 else 0)
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)
print(df_shuffled.shape)
print(df.shape)
x = df_shuffled.drop(['id','cycle','RUL', 'max', 'RULC'], axis=1)
y = df_shuffled['RULC']

# x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.21, random_state=42)
# scaler = MinMaxScaler()
# x_train_scaled = scaler.fit_transform(x_train)
# x_test_scaled = scaler.transform(x_test)
x_train,x_test,y_train,y_test = train_test(x,y)
# Out:
# (20631, 29)
# (20631, 29)

# %%
# x_train.shape
# Out:
# (16298, 24)

# %%
xgb_model = xgb.XGBClassifier(
    colsample_bytree=0.8,
    gamma=0.1,
    grow_policy="lossguide",
    learning_rate=0.12964140540905078,
    max_depth=None,
    n_estimators=3000,
    objective="binary:logistic",
    reg_alpha=0.1,
    reg_lambda=10,
    subsample=1,
    random_state=42,
    scale_pos_weight=12
)

# %%
xgb_model.fit(x_train_scaled,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.1, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.12964140540905078,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=3000, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
save(xgb_model, 'xgb_model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 save(xgb_model)
#
# Cell In[13], line 3, in save(model)
#       1 def save(model):
#       2     i = len(info)
# ----> 3     info.update({model+'_'+str(i+1):{'acc':accuracy_score(y_test,y_pred), 'best_p':model.best_params_}})
#       4     with open(path, 'w') as file:
#       5         file,write(json.dumps(info))
#
# TypeError: unsupported operand type(s) for +: 'XGBClassifier' and 'str'

# %%
str(xgb_model)
# Out:
# "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=0.8, device=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=0.1, grow_policy='lossguide', importance_type=None,\n              interaction_constraints=None, learning_rate=0.12964140540905078,\n              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              multi_strategy=None, n_estimators=3000, n_jobs=None,\n              num_parallel_tree=None, random_state=42, ...)"
